# %% [markdown]
# # Einführung

# %% [markdown]
# # LSA

# %% [markdown]
# # statische Embeddings

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ## GloVe

# %% [markdown]
# ## FastText

# %% [markdown]
# # kontextualisierte Embeddings

# %% [markdown]
# ## Transformer

# %% [markdown]
# ## ELMo

# %% [markdown]
# ## BERT
